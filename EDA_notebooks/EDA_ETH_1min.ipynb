# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display
from pathlib import Path
from matplotlib.colors import ListedColormap, BoundaryNorm

# %%
# VSC setting: "notebook.output.textLineLimit": 170

pd.set_option('display.max_rows', None)
pd.set_option('display.precision', 9)
pd.set_option('display.float_format', '{:.6f}'.format)

# %%
asset = 'ETH' 
freq = '1min'

DATA_DIR = Path('../dataset')
path = DATA_DIR / f"{asset}_{freq}.csv"
if path.exists():
    print(f'Loading {asset} from {path}')
    df = pd.read_csv(path,index_col=0)
    df['timestamp'] = pd.to_datetime(df["system_time"])
    df['timestamp'] = df['timestamp'].dt.round('min')
    df = df.sort_values('timestamp').set_index('timestamp')
print(f"{asset}: {df.shape[0]} rows, {df.shape[1]} columns")
display(df.head(3))
# Out:
# Loading ETH from ../dataset/ETH_1min.csv
# ETH: 17110 rows, 155 columns
#                                                 system_time    midpoint  \
# timestamp
# 2021-04-07 11:34:00+00:00  2021-04-07 11:33:49.861733+00:00 1965.845000
# 2021-04-07 11:35:00+00:00  2021-04-07 11:34:49.861733+00:00 1969.645000
# 2021-04-07 11:36:00+00:00  2021-04-07 11:35:49.861733+00:00 1975.595000
#
#                             spread          buys          sells  \
# timestamp
# 2021-04-07 11:34:00+00:00 0.010000 875154.482918 1684773.987938
# 2021-04-07 11:35:00+00:00 0.650000 514168.079888  858218.969496
# 2021-04-07 11:36:00+00:00 0.290000 729915.129243 1446983.975930
#
#                            bids_distance_0  bids_distance_1  bids_distance_2  \
# timestamp
# 2021-04-07 11:34:00+00:00        -0.000003        -0.000155        -0.000160
# 2021-04-07 11:35:00+00:00        -0.000165        -0.000190        -0.000201
# 2021-04-07 11:36:00+00:00        -0.000073        -0.000078        -0.000094
#
#                            bids_distance_3  bids_distance_4  ...  \
# timestamp                                                    ...
# 2021-04-07 11:34:00+00:00        -0.000257        -0.000262  ...
# 2021-04-07 11:35:00+00:00        -0.000206        -0.000216  ...
# 2021-04-07 11:36:00+00:00        -0.000099        -0.000195  ...
#
#                            asks_market_notional_5  asks_market_notional_6  \
# timestamp
# 2021-04-07 11:34:00+00:00                0.000000                0.000000
# 2021-04-07 11:35:00+00:00                0.000000                0.000000
# 2021-04-07 11:36:00+00:00                0.000000                0.000000
#
#                            asks_market_notional_7  asks_market_notional_8  \
# timestamp
# 2021-04-07 11:34:00+00:00                0.000000                0.000000
# 2021-04-07 11:35:00+00:00                0.000000                0.000000
# 2021-04-07 11:36:00+00:00                0.000000                0.000000
#
#                            asks_market_notional_9  asks_market_notional_10  \
# timestamp
# 2021-04-07 11:34:00+00:00                0.000000                 0.000000
# 2021-04-07 11:35:00+00:00                0.000000                 0.000000
# 2021-04-07 11:36:00+00:00                0.000000                 0.000000
#
#                            asks_market_notional_11  asks_market_notional_12  \
# timestamp
# 2021-04-07 11:34:00+00:00                 0.000000                 0.000000
# 2021-04-07 11:35:00+00:00                 0.000000                 0.000000
# 2021-04-07 11:36:00+00:00                 0.000000                 0.000000
#
#                            asks_market_notional_13  asks_market_notional_14
# timestamp
# 2021-04-07 11:34:00+00:00                 0.000000                 0.000000
# 2021-04-07 11:35:00+00:00                 0.000000                 0.000000
# 2021-04-07 11:36:00+00:00                 0.000000                 0.000000
#
# [3 rows x 155 columns]

# %% [markdown]
# ## Missing and Zero values

# %%
print(f"Missing values: {df.isna().sum().sum()} total ({(df.isna().sum().sum()/df.size)*100:.3f}%)")
# Out:
# Missing values: 0 total (0.000%)

# %% [markdown]
# There are no missing values

# %%
print(f"Zero values: {df.isin([0]).sum().sum()} total ({(df.isin([0]).sum().sum()/df.size)*100:.3f}%)")
# Out:
# Zero values: 813158 total (30.661%)

# %% [markdown]
# But there are a lot of Zero values

# %%
# check for all columns except those related to 'market', 'cancel', 'limit'
most_zeros = df.columns.str.contains('market|cancel|limit', case=False)

print(f"Zero values without market/cancel/limit columns: {df[df.columns[~most_zeros]].isin([0]).sum().sum()} total ({(df[df.columns[~most_zeros]].isin([0]).sum().sum()/df[df.columns[~most_zeros]].size)*100:.3f}%)")
df[df.columns[~most_zeros]].isin([0]).sum().nlargest(5)
# Out:
# Zero values without market/cancel/limit columns: 23 total (0.002%)
# asks_notional_0    12
# bids_notional_0     8
# bids_notional_6     1
# bids_notional_7     1
# asks_notional_1     1
# dtype: int64

# %% [markdown]
# Most zero values are in additional descriptive columns {'market', 'cancel', 'limit'}

# %%
market_columns = df.columns.str.contains('market', case=False)

print(f"Zero values in market columns: {df[df.columns[market_columns]].isin([0]).sum().sum()} total ({(df[df.columns[market_columns]].isin([0]).sum().sum()/df[df.columns[market_columns]].size)*100:.3f}%)")
df[df.columns[market_columns]].isin([0]).sum().sort_values(ascending=False)
# Out:
# Zero values in market columns: 481747 total (93.853%)
# bids_market_notional_14    16877
# bids_market_notional_12    16832
# bids_market_notional_13    16827
# bids_market_notional_11    16820
# bids_market_notional_9     16777
# asks_market_notional_14    16760
# bids_market_notional_10    16758
# asks_market_notional_13    16756
# asks_market_notional_12    16746
# bids_market_notional_8     16734
# bids_market_notional_7     16719
# asks_market_notional_11    16715
# bids_market_notional_6     16678
# asks_market_notional_10    16677
# asks_market_notional_9     16618
# bids_market_notional_5     16612
# asks_market_notional_8     16557
# bids_market_notional_4     16551
# asks_market_notional_7     16517
# bids_market_notional_3     16455
# asks_market_notional_6     16424
# asks_market_notional_5     16316
# bids_market_notional_2     16275
# asks_market_notional_4     16242
# asks_market_notional_3     16057
# bids_market_notional_1     15923
# asks_market_notional_2     15712
# asks_market_notional_1     14930
# bids_market_notional_0     11417
# asks_market_notional_0      8465
# dtype: int64

# %%
cancel_columns = df.columns.str.contains('cancel', case=False)

print(f"Zero values in cancel columns: {df[df.columns[cancel_columns]].isin([0]).sum().sum()} total ({(df[df.columns[cancel_columns]].isin([0]).sum().sum()/df[df.columns[cancel_columns]].size)*100:.3f}%)")
df[df.columns[cancel_columns]].isin([0]).sum().sort_values(ascending=False)
# Out:
# Zero values in cancel columns: 329912 total (64.273%)
# bids_cancel_notional_8     11742
# bids_cancel_notional_10    11714
# bids_cancel_notional_9     11678
# bids_cancel_notional_11    11678
# bids_cancel_notional_12    11658
# bids_cancel_notional_7     11644
# bids_cancel_notional_6     11578
# bids_cancel_notional_13    11562
# bids_cancel_notional_14    11415
# asks_cancel_notional_8     11332
# asks_cancel_notional_11    11300
# asks_cancel_notional_10    11285
# asks_cancel_notional_9     11268
# bids_cancel_notional_5     11258
# asks_cancel_notional_6     11168
# asks_cancel_notional_7     11149
# asks_cancel_notional_12    11099
# asks_cancel_notional_13    11075
# bids_cancel_notional_4     11037
# asks_cancel_notional_14    11004
# asks_cancel_notional_5     10903
# bids_cancel_notional_1     10795
# bids_cancel_notional_2     10643
# asks_cancel_notional_4     10571
# bids_cancel_notional_3     10540
# asks_cancel_notional_2     10402
# asks_cancel_notional_1     10354
# asks_cancel_notional_3     10116
# asks_cancel_notional_0      9012
# bids_cancel_notional_0      8932
# dtype: int64

# %%
limit_columns = df.columns.str.contains('limit', case=False)

print(f"Zero values in limit columns: {df[df.columns[limit_columns]].isin([0]).sum().sum()} total ({(df[df.columns[limit_columns]].isin([0]).sum().sum()/df[df.columns[limit_columns]].size)*100:.3f}%)")
df[df.columns[limit_columns]].isin([0]).sum().sort_values(ascending=False)
# Out:
# Zero values in limit columns: 1476 total (0.288%)
# asks_limit_notional_14    110
# asks_limit_notional_13    103
# asks_limit_notional_11     86
# asks_limit_notional_12     83
# bids_limit_notional_14     80
# asks_limit_notional_10     78
# bids_limit_notional_13     76
# asks_limit_notional_9      65
# asks_limit_notional_6      58
# bids_limit_notional_10     56
# asks_limit_notional_8      56
# bids_limit_notional_12     54
# asks_limit_notional_4      51
# asks_limit_notional_5      50
# asks_limit_notional_7      48
# bids_limit_notional_9      45
# bids_limit_notional_11     41
# asks_limit_notional_3      40
# bids_limit_notional_7      34
# asks_limit_notional_2      34
# bids_limit_notional_4      31
# bids_limit_notional_8      31
# asks_limit_notional_1      28
# bids_limit_notional_6      27
# bids_limit_notional_3      24
# bids_limit_notional_5      21
# bids_limit_notional_2      21
# bids_limit_notional_1      20
# bids_limit_notional_0      15
# asks_limit_notional_0      10
# dtype: int64

# %% [markdown]
# Market and Cancel columns can include up to 90% of zero values (even for the 1st or 2nd level)
#
# Limit_Notinal Asks and Bids include just a few zero values.

# %%
fig, ax = plt.subplots(figsize=(14, 5))
sns.heatmap(df == 0, cbar=False, ax=ax)
plt.title(f'{asset}_{freq} - Zero Values (beige) Heatmap', fontsize=26)
plt.show()

# %%
threshold_0 = 1e-7 
bins = np.array([threshold_0, 1.0])
data_abs = df.select_dtypes(include=[np.number]).abs().values
categories = np.digitize(data_abs, bins)

cmap_colors = ["#000000",  # 0
               "#ffc353",  #  (0, 1]
               "#f36fff"]  #  > 1
cmap = ListedColormap(cmap_colors)
norm = BoundaryNorm([0, 1, 2, 3], cmap.N) 


fig, ax = plt.subplots(figsize=(30, 8))
sns.heatmap(categories, 
            cmap=cmap, 
            norm=norm, 
            cbar=False,  
            ax=ax,
            xticklabels=df.select_dtypes(include=[np.number]).columns)

ax.set_title(f'{asset}_{freq} -  Zero-Value (black) & 0-1 Values (orange) & >1 Values (pink) Heatmap', fontsize=26)
plt.show()

# %% [markdown]
# Overall the data is well marked because there are no missing values and Zero values happens usually happens in the columns that are logically correct (Market and Cancel bids and asks). In the cryptocurancy the vast of trade orders are executed via "limit" operations, which is approved by the data.

# %% [markdown]
# ## General statistics

# %%
# VSC setting: "notebook.output.textLineLimit": 170

pd.set_option('display.max_rows', None)
pd.set_option('display.precision', 9)
pd.set_option('display.float_format', '{:.6f}'.format)

display(df.describe().transpose())

pd.reset_option('display.float_format')
# Out:
#                                count          mean           std         min  \
# midpoint                17110.000000   2227.385540    154.629153 1937.430000
# spread                  17110.000000      0.153281      0.240279    0.010000
# buys                    17110.000000 185933.743742 269801.884804  833.221972
# sells                   17110.000000 158002.630774 344861.500006   42.955611
# bids_distance_0         17110.000000     -0.000034      0.000055   -0.002831
# bids_distance_1         17110.000000     -0.000078      0.000080   -0.002884
# bids_distance_2         17110.000000     -0.000120      0.000097   -0.002943
# bids_distance_3         17110.000000     -0.000156      0.000112   -0.002992
# bids_distance_4         17110.000000     -0.000189      0.000128   -0.004494
# bids_distance_5         17110.000000     -0.000221      0.000139   -0.004923
# bids_distance_6         17110.000000     -0.000251      0.000152   -0.005405
# bids_distance_7         17110.000000     -0.000281      0.000162   -0.006232
# bids_distance_8         17110.000000     -0.000311      0.000175   -0.007522
# bids_distance_9         17110.000000     -0.000340      0.000187   -0.008418
# bids_distance_10        17110.000000     -0.000369      0.000202   -0.008428
# bids_distance_11        17110.000000     -0.000397      0.000223   -0.011129
# bids_distance_12        17110.000000     -0.000426      0.000233   -0.011133
# bids_distance_13        17110.000000     -0.000454      0.000241   -0.011138
# bids_distance_14        17110.000000     -0.000482      0.000247   -0.011151
# bids_notional_0         17110.000000  27760.379389  67967.223450   -0.000000
# bids_notional_1         17110.000000  12382.415513  34894.586954    0.050000
# bids_notional_2         17110.000000  14000.734171  34166.313354    0.160000
# bids_notional_3         17110.000000  13554.885246  22588.107992    0.160000
# bids_notional_4         17110.000000  14362.109051  32342.542229    0.110000
# bids_notional_5         17110.000000  13692.211834  19740.449797    0.060000
# bids_notional_6         17110.000000  13831.362582  33438.902309    0.000000
# bids_notional_7         17110.000000  13232.795441  19631.732974    0.000000
# bids_notional_8         17110.000000  13102.581751  18216.126226    0.090000
# bids_notional_9         17110.000000  13497.451632  27228.644199    0.550000
# bids_notional_10        17110.000000  13282.376586  26756.711341    0.060000
# bids_notional_11        17110.000000  12802.415767  23007.706016    0.030000
# bids_notional_12        17110.000000  13132.408130  31954.713398    1.970000
# bids_notional_13        17110.000000  12554.644291  19574.424290    0.060000
# bids_notional_14        17110.000000  12812.131571  20819.831384    0.900000
# bids_cancel_notional_0  17110.000000  79528.111631 242745.896172    0.000000
# bids_cancel_notional_1  17110.000000  26891.253531 117220.870209    0.000000
# bids_cancel_notional_2  17110.000000  19204.764056  79701.463788    0.000000
# bids_cancel_notional_3  17110.000000  18795.430981  79157.032995    0.000000
# asks_limit_notional_9    3874.737488  15543.694824  27798.333008
# asks_limit_notional_10   3874.132385  15570.479980  28144.737793
# asks_limit_notional_11   3873.530029  15197.040039  29005.554688
# asks_limit_notional_12   3873.452454  15470.975098  29983.987793
# asks_limit_notional_13   3873.050049  15211.084961  30031.664551
# asks_limit_notional_14   3872.732483  15080.084961  30911.057617
# asks_market_notional_0      0.000000      3.930000    869.474991
# asks_market_notional_1      0.000000      0.000000      0.000000
# asks_market_notional_2      0.000000      0.000000      0.000000
# asks_market_notional_3      0.000000      0.000000      0.000000
# asks_market_notional_4      0.000000      0.000000      0.000000
# asks_market_notional_5      0.000000      0.000000      0.000000
# asks_market_notional_6      0.000000      0.000000      0.000000
# asks_market_notional_7      0.000000      0.000000      0.000000
# asks_market_notional_8      0.000000      0.000000      0.000000
# asks_market_notional_9      0.000000      0.000000      0.000000
# asks_market_notional_10     0.000000      0.000000      0.000000
# asks_market_notional_11     0.000000      0.000000      0.000000
# asks_market_notional_12     0.000000      0.000000      0.000000
# asks_market_notional_13     0.000000      0.000000      0.000000
# asks_market_notional_14     0.000000      0.000000      0.000000
#
#                                     max
# midpoint                    2546.405000
# spread                        11.640000
# buys                     4663486.812841
# sells                   11116638.814593
# bids_distance_0               -0.000002
# bids_distance_1               -0.000006
# bids_distance_2               -0.000010
# bids_distance_3               -0.000014
# bids_distance_4               -0.000018
# bids_distance_5               -0.000024
# bids_distance_6               -0.000030
# bids_distance_7               -0.000035
# bids_distance_8               -0.000042
# bids_distance_9               -0.000048
# bids_distance_10              -0.000054
# bids_distance_11              -0.000087
# bids_distance_12              -0.000095
# bids_distance_13              -0.000122
# bids_distance_14              -0.000136
# bids_notional_0          2457896.750000
# bids_notional_1          2484409.500000
# bids_notional_2          1885365.750000
# bids_notional_3           883487.250000
# bids_notional_4          2583377.250000
# bids_notional_5           565254.875000
# bids_notional_6          1907566.750000
# bids_notional_7          1036279.250000
# bids_notional_8           485291.812500
# bids_notional_9          1343101.875000
# bids_notional_10         1343100.000000
# bids_notional_11         1189410.000000
# bids_notional_12         2050650.625000
# bids_notional_13          964969.437500
# bids_notional_14          883528.437500
# bids_cancel_notional_0   6307393.000000
# bids_cancel_notional_1   4756787.000000
# bids_cancel_notional_2   1943757.125000
# bids_cancel_notional_3   2349558.000000
# bids_cancel_notional_4   5179568.000000
# bids_cancel_notional_5  22680624.000000
# bids_cancel_notional_6   4802547.500000
# bids_cancel_notional_7   2628996.250000
# bids_cancel_notional_8   2980796.750000
# bids_cancel_notional_9   5298857.500000
# bids_cancel_notional_10  1986633.625000
# bids_cancel_notional_11  2964889.000000
# bids_cancel_notional_12  2565682.750000
# bids_cancel_notional_13  2282327.500000
# bids_cancel_notional_14  2111808.000000
# bids_limit_notional_0    6472384.500000
# bids_limit_notional_1    4832501.000000
# bids_limit_notional_2    1956195.250000
# bids_limit_notional_3    2430907.000000
# bids_limit_notional_4    5216790.000000
# bids_limit_notional_5   22680818.000000
# bids_limit_notional_6    5866917.000000
# bids_limit_notional_7    2668456.750000
# bids_limit_notional_8    3015629.750000
# bids_limit_notional_9    5356685.000000
# bids_limit_notional_10   2019115.125000
# bids_limit_notional_11   3305748.750000
# bids_limit_notional_12   2584694.500000
# bids_limit_notional_13   2302406.000000
# bids_limit_notional_14   2143403.250000
# bids_market_notional_0   1298825.125000
# bids_market_notional_1    196131.218750
# bids_market_notional_2    495992.125000
# bids_market_notional_3    882453.750000
# bids_market_notional_4    665191.437500
# bids_market_notional_5    129222.968750
# bids_market_notional_6   2547446.500000
# bids_market_notional_7    101885.679688
# bids_market_notional_8    195534.593750
# bids_market_notional_9   1988409.750000
# bids_market_notional_10   648512.375000
# bids_market_notional_11  2214793.000000
# bids_market_notional_12   271023.375000
# bids_market_notional_13  1402383.875000
# bids_market_notional_14    61592.050781
# asks_distance_0                0.002831
# asks_distance_1                0.002841
# asks_distance_2                0.004018
# asks_distance_3                0.004023
# asks_distance_4                0.004332
# asks_distance_5                0.004450
# asks_distance_6                0.004558
# asks_distance_7                0.005026
# asks_distance_8                0.007181
# asks_distance_9                0.007190
# asks_distance_10               0.009070
# asks_distance_11               0.012131
# asks_distance_12               0.013245
# asks_distance_13               0.013250
# asks_distance_14               0.013402
# asks_notional_0          7403558.000000
# asks_notional_1          4807323.000000
# asks_notional_2          4072860.000000
# asks_notional_3          4807049.500000
# asks_notional_4          7425843.500000
# asks_notional_5          5022209.000000
# asks_notional_6          6736250.000000
# asks_notional_7          4365925.000000
# asks_notional_8          4130699.250000
# asks_notional_9          2097817.500000
# asks_notional_10         6736611.500000
# asks_notional_11         1488267.750000
# asks_notional_12         2239983.750000
# asks_notional_13         4868444.500000
# asks_notional_14         7425843.500000
# asks_cancel_notional_0  11280893.000000
# asks_cancel_notional_1   5288169.000000
# asks_cancel_notional_2   3308473.000000
# asks_cancel_notional_3   4288051.000000
# asks_cancel_notional_4   4244571.000000
# asks_cancel_notional_5  94993152.000000
# asks_cancel_notional_6   2425338.500000
# asks_cancel_notional_7   2229049.750000
# asks_cancel_notional_8   2360948.500000
# asks_cancel_notional_9  77984176.000000
# asks_cancel_notional_10  3938575.250000
# asks_cancel_notional_11 12296280.000000
# asks_cancel_notional_12  1933710.375000
# asks_cancel_notional_13  3539794.750000
# asks_cancel_notional_14  2638490.750000
# asks_limit_notional_0   12138815.000000
# asks_limit_notional_1    5394305.500000
# asks_limit_notional_2    3554358.250000
# asks_limit_notional_3    4287846.000000
# asks_limit_notional_4    4244571.000000
# asks_limit_notional_5   94995440.000000
# asks_limit_notional_6    2509380.000000
# asks_limit_notional_7    2229049.750000
# asks_limit_notional_8    4134573.000000
# asks_limit_notional_9   80069672.000000
# asks_limit_notional_10   4534723.500000
# asks_limit_notional_11  12298738.000000
# asks_limit_notional_12   1960046.750000
# asks_limit_notional_13   3788742.500000
# asks_limit_notional_14   2555804.000000
# asks_market_notional_0   2611694.250000
# asks_market_notional_1    810119.625000
# asks_market_notional_2    501982.531250
# asks_market_notional_3   1390768.875000
# asks_market_notional_4    645792.062500
# asks_market_notional_5   1352306.500000
# asks_market_notional_6    702773.937500
# asks_market_notional_7    397918.250000
# asks_market_notional_8    815787.937500
# asks_market_notional_9    265074.875000
# asks_market_notional_10   858927.437500
# asks_market_notional_11   338109.000000
# asks_market_notional_12   805324.812500
# asks_market_notional_13   274563.375000
# asks_market_notional_14   228892.765625

# %% [markdown]
# The only negative are "bids_distance_X", because they are calculated as "behind" midpoint.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['midpoint'], label='Midpoint', linewidth=1.5)
plt.plot(df.index, (1+df['bids_distance_14'])*df['midpoint'], label='Bid Distance 14', linewidth=0.5, alpha=0.5)
plt.plot(df.index, (1+df['asks_distance_14'])*df['midpoint'], label='Ask Distance 14', linewidth=0.5, alpha=0.5)
plt.legend()
plt.title(f'Midpoint over Time – {asset} {freq}', fontsize=16)
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()

# %%
df_1day = df[df.index <= (df.index.min() + pd.Timedelta('2 hours'))]

plt.figure(figsize=(18, 10))
plt.plot(df_1day.index, df_1day['midpoint'], label='Midpoint', linewidth=1)
plt.plot(df_1day.index, (1+df_1day['bids_distance_14'])*df_1day['midpoint'], label='Bid Distance 14', linewidth=0.8, alpha=0.8)
plt.plot(df_1day.index, (1+df_1day['asks_distance_14'])*df_1day['midpoint'], label='Ask Distance 14', linewidth=0.8, alpha=0.8)
plt.legend()
plt.title(f'Midpoint over 2 hours – {asset} {freq}', fontsize=16)
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ## Example of 3 rows

# %%
# VSC setting: "notebook.output.textLineLimit": 170

pd.reset_option('display.precision')
pd.reset_option('display.float_format')

transposed_df = df.head(3).transpose()
display(transposed_df)
# Out:
# timestamp                       2021-04-07 11:34:00+00:00  \
# system_time              2021-04-07 11:33:49.861733+00:00
# midpoint                                         1965.845
# spread                                               0.01
# buys                                        875154.482918
# sells                                      1684773.987938
# bids_distance_0                                 -0.000003
# bids_distance_1                                 -0.000155
# bids_distance_2                                  -0.00016
# bids_distance_3                                 -0.000257
# bids_distance_4                                 -0.000262
# bids_distance_5                                 -0.000277
# bids_distance_6                                 -0.000425
# bids_distance_7                                  -0.00043
# bids_distance_8                                 -0.000455
# bids_distance_9                                 -0.000506
# bids_distance_10                                -0.000532
# bids_distance_11                                -0.000547
# bids_distance_12                                -0.000593
# bids_distance_13                                -0.000613
# bids_distance_14                                -0.000674
# bids_notional_0                              44445.929688
# bids_notional_1                               7766.830078
# bids_notional_2                                196.550003
# bids_notional_3                               9972.139648
# bids_notional_4                              42644.878906
# bids_notional_5                                  34927.25
# bids_notional_6                              19519.410156
# bids_notional_7                               12016.94043
# bids_notional_8                                514.400024
# bids_notional_9                                751.210022
# bids_notional_10                              2057.439941
# bids_notional_11                                760.76001
# bids_notional_12                              4954.089844
# bids_notional_13                              4995.359863
# bids_notional_14                               1998.48999
# bids_cancel_notional_0                       42265.558594
# bids_cancel_notional_1                         1883.47998
# bids_cancel_notional_2                       29482.949219
# bids_cancel_notional_3                                0.0
# bids_cancel_notional_4                       41288.148438
# bids_cancel_notional_5                                0.0
# bids_cancel_notional_6                                0.0
# bids_cancel_notional_7                                0.0
# bids_cancel_notional_8                                0.0
# bids_cancel_notional_9                                0.0
# bids_cancel_notional_10                               0.0
# bids_cancel_notional_11                               0.0
# bids_cancel_notional_12                               0.0
# bids_cancel_notional_13                               0.0
# bids_cancel_notional_14                               0.0
# bids_limit_notional_0                        86711.492188
# bids_limit_notional_1                          9650.30957
# bids_limit_notional_2                             29679.5
# bids_limit_notional_3                         9972.139648
# bids_limit_notional_4                         83933.03125
# bids_limit_notional_5                            34927.25
# bids_limit_notional_6                        19519.410156
# bids_limit_notional_7                            14049.75
# bids_limit_notional_8                          514.400024
# bids_limit_notional_9                          751.210022
# bids_limit_notional_10                        2057.439941
# bids_limit_notional_11                          760.76001
# bids_limit_notional_12                        4954.089844
# bids_limit_notional_13                        4995.359863
# bids_limit_notional_14                         1998.48999
# bids_market_notional_0                                0.0
# bids_market_notional_1                                0.0
# bids_market_notional_2                                0.0
# bids_market_notional_3                                0.0
# bids_market_notional_4                                0.0
# bids_market_notional_5                                0.0
# bids_market_notional_6                                0.0
# bids_market_notional_7                        2032.810059
# bids_market_notional_8                                0.0
# bids_market_notional_9                                0.0
# bids_market_notional_10                               0.0
# bids_market_notional_11                               0.0
# bids_market_notional_12                               0.0
# bids_market_notional_13                               0.0
# bids_market_notional_14                               0.0
# asks_distance_0                                  0.000003
# asks_distance_1                                  0.000135
# asks_distance_2                                   0.00014
# asks_distance_3                                  0.000196
# asks_distance_4                                  0.000242
# asks_distance_5                                  0.000277
# asks_distance_6                                  0.000415
# asks_distance_7                                  0.000455
# asks_distance_8                                  0.000511
# asks_distance_9                                  0.000567
# asks_distance_10                                 0.000572
# asks_distance_11                                 0.000588
# asks_distance_12                                 0.000623
# asks_distance_13                                 0.000628
# asks_distance_14                                 0.000633
# asks_notional_0                                      1.08
# asks_notional_1                                   3234.25
# asks_notional_2                              20005.310547
# asks_notional_3                               4350.029785
# asks_notional_4                               3873.649902
# asks_notional_5                              20005.439453
# asks_notional_6                               3874.320068
# asks_notional_7                                731.830017
# asks_notional_8                                373.700012
# asks_notional_9                                196.699997
# asks_notional_10                              2059.709961
# asks_notional_11                               3874.98999
# asks_notional_12                              5901.209961
# asks_notional_13                               178.289993
# asks_notional_14                             28512.160156
# asks_cancel_notional_0                                0.0
# asks_cancel_notional_1                                0.0
# asks_cancel_notional_2                                0.0
# asks_cancel_notional_3                                0.0
# asks_cancel_notional_4                        1966.319946
# asks_cancel_notional_5                                0.0
# asks_cancel_notional_6                                0.0
# asks_cancel_notional_7                                0.0
# asks_cancel_notional_8                                0.0
# asks_cancel_notional_9                                0.0
# asks_cancel_notional_10                               0.0
# asks_cancel_notional_11                               0.0
# asks_cancel_notional_12                               0.0
# asks_cancel_notional_13                               0.0
# asks_cancel_notional_14                               0.0
# asks_limit_notional_0                        20005.570312
# asks_limit_notional_1                             3234.25
# asks_limit_notional_2                        20005.310547
# asks_limit_notional_3                         4350.029785
# asks_limit_notional_4                         5839.970215
# asks_limit_notional_5                        20005.439453
# asks_limit_notional_6                         3874.320068
# asks_limit_notional_7                          731.830017
# asks_limit_notional_8                          373.700012
# asks_limit_notional_9                          196.699997
# asks_limit_notional_10                        2059.709961
# asks_limit_notional_11                         3874.98999
# asks_limit_notional_12                        5901.209961
# asks_limit_notional_13                         178.289993
# asks_limit_notional_14                       28512.160156
# asks_market_notional_0                       20004.490234
# asks_market_notional_1                                0.0
# asks_market_notional_2                                0.0
# asks_market_notional_3                                0.0
# asks_market_notional_4                                0.0
# asks_market_notional_5                                0.0
# asks_market_notional_6                                0.0
# asks_market_notional_7                                0.0
# asks_market_notional_8                                0.0
# asks_market_notional_9                                0.0
# asks_market_notional_10                               0.0
# asks_market_notional_11                               0.0
# asks_market_notional_12                               0.0
# asks_market_notional_13                               0.0
# asks_market_notional_14                               0.0
#
# timestamp                       2021-04-07 11:35:00+00:00  \
# system_time              2021-04-07 11:34:49.861733+00:00
# midpoint                                         1969.645
# spread                                               0.65
# buys                                        514168.079888
# sells                                       858218.969496
# bids_distance_0                                 -0.000165
# bids_distance_1                                  -0.00019
# bids_distance_2                                 -0.000201
# bids_distance_3                                 -0.000206
# bids_distance_4                                 -0.000216
# bids_distance_5                                 -0.000256
# bids_distance_6                                 -0.000267
# bids_distance_7                                 -0.000272
# bids_distance_8                                 -0.000297
# bids_distance_9                                 -0.000302
# bids_distance_10                                -0.000322
# bids_distance_11                                -0.000327
# bids_distance_12                                -0.000475
# bids_distance_13                                 -0.00048
# bids_distance_14                                -0.000531
# bids_notional_0                              29539.800781
# bids_notional_1                               1031.329956
# bids_notional_2                               2736.439941
# bids_notional_3                               9811.919922
# bids_notional_4                              29572.099609
# bids_notional_5                              35760.148438
# bids_notional_6                              30945.970703
# bids_notional_7                                      9.85
# bids_notional_8                               4995.720215
# bids_notional_9                                6640.97998
# bids_notional_10                               197.029999
# bids_notional_11                               196.899994
# bids_notional_12                               984.359985
# bids_notional_13                              5906.100098
# bids_notional_14                               732.440002
# bids_cancel_notional_0                                0.0
# bids_cancel_notional_1                                0.0
# bids_cancel_notional_2                                0.0
# bids_cancel_notional_3                        1031.310059
# bids_cancel_notional_4                        2736.389893
# bids_cancel_notional_5                        2736.280029
# bids_cancel_notional_6                                0.0
# bids_cancel_notional_7                        5543.689941
# bids_cancel_notional_8                                0.0
# bids_cancel_notional_9                                0.0
# bids_cancel_notional_10                               0.0
# bids_cancel_notional_11                               0.0
# bids_cancel_notional_12                               0.0
# bids_cancel_notional_13                       4995.720215
# bids_cancel_notional_14                               0.0
# bids_limit_notional_0                        29539.800781
# bids_limit_notional_1                         1031.329956
# bids_limit_notional_2                         2736.439941
# bids_limit_notional_3                        10843.230469
# bids_limit_notional_4                        32308.490234
# bids_limit_notional_5                        38496.429688
# bids_limit_notional_6                        30945.970703
# bids_limit_notional_7                         5553.529785
# bids_limit_notional_8                         4995.720215
# bids_limit_notional_9                          6640.97998
# bids_limit_notional_10                         197.029999
# bids_limit_notional_11                         196.899994
# bids_limit_notional_12                         984.359985
# bids_limit_notional_13                       10901.820312
# bids_limit_notional_14                         732.440002
# bids_market_notional_0                                0.0
# bids_market_notional_1                                0.0
# bids_market_notional_2                                0.0
# bids_market_notional_3                                0.0
# bids_market_notional_4                                0.0
# bids_market_notional_5                                0.0
# bids_market_notional_6                                0.0
# bids_market_notional_7                                0.0
# bids_market_notional_8                                0.0
# bids_market_notional_9                                0.0
# bids_market_notional_10                               0.0
# bids_market_notional_11                               0.0
# bids_market_notional_12                               0.0
# bids_market_notional_13                               0.0
# bids_market_notional_14                               0.0
# asks_distance_0                                  0.000165
# asks_distance_1                                  0.000175
# asks_distance_2                                   0.00018
# asks_distance_3                                   0.00019
# asks_distance_4                                  0.000216
# asks_distance_5                                  0.000287
# asks_distance_6                                  0.000307
# asks_distance_7                                  0.000353
# asks_distance_8                                  0.000358
# asks_distance_9                                  0.000378
# asks_distance_10                                 0.000404
# asks_distance_11                                 0.000444
# asks_distance_12                                 0.000449
# asks_distance_13                                 0.000459
# asks_distance_14                                 0.000531
# asks_notional_0                                172.059998
# asks_notional_1                              29840.800781
# asks_notional_2                              1003755.1875
# asks_notional_3                               3873.060059
# asks_notional_4                              20216.859375
# asks_notional_5                              20009.779297
# asks_notional_6                              20004.830078
# asks_notional_7                                733.619995
# asks_notional_8                               3873.709961
# asks_notional_9                               1954.630005
# asks_notional_10                               197.039993
# asks_notional_11                             12661.990234
# asks_notional_12                             20006.970703
# asks_notional_13                             28562.310547
# asks_notional_14                              3874.379883
# asks_cancel_notional_0                       36491.148438
# asks_cancel_notional_1                                0.0
# asks_cancel_notional_2                                0.0
# asks_cancel_notional_3                                0.0
# asks_cancel_notional_4                                0.0
# asks_cancel_notional_5                                0.0
# asks_cancel_notional_6                                0.0
# asks_cancel_notional_7                                0.0
# asks_cancel_notional_8                                0.0
# asks_cancel_notional_9                                0.0
# asks_cancel_notional_10                               0.0
# asks_cancel_notional_11                               0.0
# asks_cancel_notional_12                               0.0
# asks_cancel_notional_13                               0.0
# asks_cancel_notional_14                               0.0
# asks_limit_notional_0                        36921.578125
# asks_limit_notional_1                        29840.800781
# asks_limit_notional_2                        1003755.1875
# asks_limit_notional_3                         3873.060059
# asks_limit_notional_4                        20216.859375
# asks_limit_notional_5                        20009.779297
# asks_limit_notional_6                        20004.830078
# asks_limit_notional_7                          733.619995
# asks_limit_notional_8                         3873.709961
# asks_limit_notional_9                         1954.630005
# asks_limit_notional_10                         197.039993
# asks_limit_notional_11                       12661.990234
# asks_limit_notional_12                       20006.970703
# asks_limit_notional_13                       28562.310547
# asks_limit_notional_14                        3874.379883
# asks_market_notional_0                         258.369995
# asks_market_notional_1                                0.0
# asks_market_notional_2                                0.0
# asks_market_notional_3                                0.0
# asks_market_notional_4                                0.0
# asks_market_notional_5                                0.0
# asks_market_notional_6                                0.0
# asks_market_notional_7                                0.0
# asks_market_notional_8                                0.0
# asks_market_notional_9                                0.0
# asks_market_notional_10                               0.0
# asks_market_notional_11                               0.0
# asks_market_notional_12                               0.0
# asks_market_notional_13                               0.0
# asks_market_notional_14                               0.0
#
# timestamp                       2021-04-07 11:36:00+00:00
# system_time              2021-04-07 11:35:49.861733+00:00
# midpoint                                         1975.595
# spread                                               0.29
# buys                                        729915.129243
# sells                                       1446983.97593
# bids_distance_0                                 -0.000073
# bids_distance_1                                 -0.000078
# bids_distance_2                                 -0.000094
# bids_distance_3                                 -0.000099
# bids_distance_4                                 -0.000195
# bids_distance_5                                 -0.000271
# bids_distance_6                                 -0.000281
# bids_distance_7                                 -0.000321
# bids_distance_8                                 -0.000332
# bids_distance_9                                 -0.000519
# bids_distance_10                                -0.000524
# bids_distance_11                                -0.000534
# bids_distance_12                                -0.000564
# bids_distance_13                                -0.000569
# bids_distance_14                                -0.000605
# bids_notional_0                               1278.369995
# bids_notional_1                               2453.889893
# bids_notional_2                                197.539993
# bids_notional_3                                 755.97998
# bids_notional_4                               5925.629883
# bids_notional_5                               8410.410156
# bids_notional_6                                187.970001
# bids_notional_7                                917.099976
# bids_notional_8                                729.460022
# bids_notional_9                               4867.529785
# bids_notional_10                             24078.490234
# bids_notional_11                                987.27002
# bids_notional_12                              1144.709961
# bids_notional_13                             25839.890625
# bids_notional_14                               713.710022
# bids_cancel_notional_0                                0.0
# bids_cancel_notional_1                                0.0
# bids_cancel_notional_2                       31013.939453
# bids_cancel_notional_3                                0.0
# bids_cancel_notional_4                        1975.209961
# bids_cancel_notional_5                                0.0
# bids_cancel_notional_6                       29625.599609
# bids_cancel_notional_7                        1974.959961
# bids_cancel_notional_8                                0.0
# bids_cancel_notional_9                                0.0
# bids_cancel_notional_10                       4995.950195
# bids_cancel_notional_11                               0.0
# bids_cancel_notional_12                         987.23999
# bids_cancel_notional_13                               0.0
# bids_cancel_notional_14                      26865.660156
# bids_limit_notional_0                         1278.369995
# bids_limit_notional_1                         2453.889893
# bids_limit_notional_2                        31211.480469
# bids_limit_notional_3                           755.97998
# bids_limit_notional_4                         7900.839844
# bids_limit_notional_5                         8410.410156
# bids_limit_notional_6                        29813.570312
# bids_limit_notional_7                         2892.060059
# bids_limit_notional_8                          729.460022
# bids_limit_notional_9                         4867.529785
# bids_limit_notional_10                       29074.429688
# bids_limit_notional_11                          987.27002
# bids_limit_notional_12                        2131.949951
# bids_limit_notional_13                       25839.890625
# bids_limit_notional_14                       27579.369141
# bids_market_notional_0                                0.0
# bids_market_notional_1                                0.0
# bids_market_notional_2                                0.0
# bids_market_notional_3                                0.0
# bids_market_notional_4                                0.0
# bids_market_notional_5                                0.0
# bids_market_notional_6                                0.0
# bids_market_notional_7                                0.0
# bids_market_notional_8                                0.0
# bids_market_notional_9                                0.0
# bids_market_notional_10                               0.0
# bids_market_notional_11                               0.0
# bids_market_notional_12                               0.0
# bids_market_notional_13                               0.0
# bids_market_notional_14                               0.0
# asks_distance_0                                  0.000073
# asks_distance_1                                  0.000235
# asks_distance_2                                  0.000372
# asks_distance_3                                  0.000377
# asks_distance_4                                  0.000382
# asks_distance_5                                  0.000407
# asks_distance_6                                  0.000448
# asks_distance_7                                  0.000504
# asks_distance_8                                  0.000519
# asks_distance_9                                  0.000524
# asks_distance_10                                  0.00058
# asks_distance_11                                 0.000585
# asks_distance_12                                 0.000752
# asks_distance_13                                 0.000757
# asks_distance_14                                 0.000762
# asks_notional_0                               2106.830078
# asks_notional_1                               3873.080078
# asks_notional_2                               5928.990234
# asks_notional_3                              19763.400391
# asks_notional_4                              28646.380859
# asks_notional_5                                3873.73999
# asks_notional_6                              26095.470703
# asks_notional_7                                743.140015
# asks_notional_8                                988.309998
# asks_notional_9                              20011.720703
# asks_notional_10                              3874.409912
# asks_notional_11                             20011.740234
# asks_notional_12                              3875.080078
# asks_notional_13                              4873.819824
# asks_notional_14                               747.340027
# asks_cancel_notional_0                         3923.73999
# asks_cancel_notional_1                                0.0
# asks_cancel_notional_2                        1046.469971
# asks_cancel_notional_3                        2092.939941
# asks_cancel_notional_4                                0.0
# asks_cancel_notional_5                                0.0
# asks_cancel_notional_6                                0.0
# asks_cancel_notional_7                                0.0
# asks_cancel_notional_8                                0.0
# asks_cancel_notional_9                       14980.879883
# asks_cancel_notional_10                               0.0
# asks_cancel_notional_11                               0.0
# asks_cancel_notional_12                               0.0
# asks_cancel_notional_13                               0.0
# asks_cancel_notional_14                        988.549988
# asks_limit_notional_0                        13438.839844
# asks_limit_notional_1                         3873.080078
# asks_limit_notional_2                         6975.459961
# asks_limit_notional_3                        21856.339844
# asks_limit_notional_4                        28646.380859
# asks_limit_notional_5                          3873.73999
# asks_limit_notional_6                        26095.470703
# asks_limit_notional_7                          743.140015
# asks_limit_notional_8                          988.309998
# asks_limit_notional_9                        34992.601562
# asks_limit_notional_10                        3874.409912
# asks_limit_notional_11                       20011.740234
# asks_limit_notional_12                        3875.080078
# asks_limit_notional_13                        4873.819824
# asks_limit_notional_14                        1735.890015
# asks_market_notional_0                         7408.27002
# asks_market_notional_1                                0.0
# asks_market_notional_2                                0.0
# asks_market_notional_3                                0.0
# asks_market_notional_4                                0.0
# asks_market_notional_5                                0.0
# asks_market_notional_6                                0.0
# asks_market_notional_7                                0.0
# asks_market_notional_8                                0.0
# asks_market_notional_9                                0.0
# asks_market_notional_10                               0.0
# asks_market_notional_11                               0.0
# asks_market_notional_12                               0.0
# asks_market_notional_13                               0.0
# asks_market_notional_14                               0.0

# %% [markdown]
# Even for the first 3 observations the data can highly variate. This is because of actively changing market.

# %%
transposed_df[transposed_df.index.str.endswith('_0')]
# Out:
# timestamp              2021-04-07 11:34:00+00:00 2021-04-07 11:35:00+00:00  \
# bids_distance_0                        -0.000003                 -0.000165
# bids_notional_0                     44445.929688              29539.800781
# bids_cancel_notional_0              42265.558594                       0.0
# bids_limit_notional_0               86711.492188              29539.800781
# bids_market_notional_0                       0.0                       0.0
# asks_distance_0                         0.000003                  0.000165
# asks_notional_0                             1.08                172.059998
# asks_cancel_notional_0                       0.0              36491.148438
# asks_limit_notional_0               20005.570312              36921.578125
# asks_market_notional_0              20004.490234                258.369995
#
# timestamp              2021-04-07 11:36:00+00:00
# bids_distance_0                        -0.000073
# bids_notional_0                      1278.369995
# bids_cancel_notional_0                       0.0
# bids_limit_notional_0                1278.369995
# bids_market_notional_0                       0.0
# asks_distance_0                         0.000073
# asks_notional_0                      2106.830078
# asks_cancel_notional_0                3923.73999
# asks_limit_notional_0               13438.839844
# asks_market_notional_0                7408.27002

# %% [markdown]
# The 0 level structure of the first 3 observations also shows that we are analysing actively changing market.

# %% [markdown]
# ## Feature relatad visualizations

# %%
print(f'{asset} {freq} shape:', df.shape)
# Out:
# ETH 1min shape: (17110, 155)

# %%
features_to_plot = ['midpoint', 'spread', 'buys', 'sells']

fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs = axs.flatten()

for i, f in enumerate(features_to_plot):
    if i==1:
        sns.histplot(df[f], bins=50, ax=axs[i], kde=True, color='steelblue')
        axs[i].set_xlim(right=axs[i].get_xlim()[1]*0.25)
        axs[i].set_title(f'Distribution of {f} (zoomed X-axis to 25% of left side)')
    elif i==2 or i==3:
        axs[i].set_xlim(right=1*1e6)
        axs[i].set_title(f'Distribution of {f} (zoomed X-axis)')
        bins = np.linspace(0, axs[i].get_xlim()[1], 50)
        sns.histplot(df[f], bins=bins, ax=axs[i], kde=True, color='steelblue')
    elif i==0:
        sns.histplot(df[f], bins=50, ax=axs[i], kde=True, color='steelblue')
        axs[i].set_title(f'Distribution of {f}')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['bids_notional_0'], label='Bid Notional 0', linewidth=1, alpha=0.8)
plt.plot(df.index, df['asks_notional_0'], label='Ask Notional 0', linewidth=1, alpha=0.8)
plt.legend()
plt.title('Midpoint over Time – {} {}'.format(asset, freq), fontsize=16)
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# There are some observations of with extreme large values of Bid/Ask notional volumes.

# %%
bid_levels = [f'bids_notional_{i}' for i in range(15)]
ask_levels = [f'asks_notional_{i}' for i in range(15)]

# Combine to 2D matrix
depth_data = pd.DataFrame({
    'timestamp': df.index,
    **{lvl: df[lvl] for lvl in bid_levels + ask_levels}
})

plt.figure(figsize=(14, 6))
sns.heatmap(depth_data[bid_levels].T, cmap='crest', cbar=True)
plt.title(f'{asset} {freq} – Bid Depth Heatmap (Levels 0–14)')
plt.show()

plt.figure(figsize=(14, 6))
sns.heatmap(depth_data[ask_levels].T, cmap='rocket', cbar=True)
plt.title(f'{asset} {freq} – Ask Depth Heatmap (Levels 0–14)')
plt.show()

# %% [markdown]
# There are just a few eye-catching spots on each heatmap. The log1p scaled potentionally show more information.

# %%
bid_levels = [f'bids_notional_{i}' for i in range(15)]
ask_levels = [f'asks_notional_{i}' for i in range(15)]

# Combine to 2D matrix
depth_data = pd.DataFrame({
    'timestamp': df.index,
    **{lvl: df[lvl] for lvl in bid_levels + ask_levels}
})

bid_data_log = np.log1p(depth_data[bid_levels].T)

plt.figure(figsize=(14, 6))
sns.heatmap(
    bid_data_log,
    cmap='mako', 
    cbar=True
)
plt.title(f'{asset} {freq} – Bid Depth Heatmap (Levels 0–14) [LOG SCALE]')
plt.show()

ask_data_log = np.log1p(depth_data[ask_levels].T)

plt.figure(figsize=(14, 6))
sns.heatmap(
    ask_data_log,
    cmap='rocket', 
    cbar=True
)
plt.title(f'{asset} {freq} – Ask Depth Heatmap (Levels 0–14) [LOG SCALE]')
plt.show()

# %% [markdown]
# At both heatmap the forst level is brighter than others (most orders executed close to the mid price). Also it is easier to understand low-volume areas (dark regions) with log scaled Notional volume. This information can be important for model.

# %% [markdown]
# ### Notional Volume

# %%
levels = range(15)
data = []

for i in levels:
    data.append(pd.DataFrame({
        'Level': [i] * len(df) * 2,
        'Type': ['Bid'] * len(df) + ['Ask'] * len(df),
        'Value': pd.concat([df[f'bids_notional_{i}'], df[f'asks_notional_{i}']], ignore_index=True)
    }))

df_box_all = pd.concat(data, ignore_index=True)

plt.figure(figsize=(14, 4))
sns.boxplot(
    data=df_box_all,
    x='Level',
    y='Value',
    hue='Type',
    palette={'Bid': 'green', 'Ask': 'red'},
    width=0.6
)
#plt.yscale('log') 
plt.title('Notional Distributions per Level ({} {})'.format(asset, freq))
plt.xlabel('Depth Level')
plt.ylabel('Notional Value (log scale)')
plt.legend(title='Order Type')
plt.tight_layout()
plt.show()

# %%
df_box_all['Value'] = np.log1p(df_box_all['Value'])

plt.figure(figsize=(14, 4))
sns.boxplot(
    data=df_box_all,
    x='Level',
    y='Value',
    hue='Type',
    palette={'Bid': 'green', 'Ask': 'red'},
    width=0.6
)

plt.title(f'{asset} {freq} - Notional Distributions per Level (Bid vs Ask, log scale)')
plt.xlabel('Depth Level')
plt.ylabel('Notional Value (log scale)')
plt.legend(title='Order Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# The most pairs of Bid/Ask are close to earch other in terms of distribution of Notional volume, except the first level, where the volume is above other levels.

# %% [markdown]
# ### Distance from midpoint

# %%
levels = range(15)
data = []

for i in levels:
    data.append(pd.DataFrame({
        'Level': [i] * len(df) * 2,
        'Type': ['Bid'] * len(df) + ['Ask'] * len(df),
        'Value': pd.concat([df[f'bids_distance_{i}']*(-1), df[f'asks_distance_{i}']], ignore_index=True)
    }))

df_box_all = pd.concat(data, ignore_index=True)

plt.figure(figsize=(14, 4))
sns.boxplot(
    data=df_box_all,
    x='Level',
    y='Value',
    hue='Type',
    palette={'Bid': 'green', 'Ask': 'red'},
    width=0.6
)

plt.yscale('log') 
plt.title(f'{asset} {freq} - Distance Distributions per Level (Bid vs Ask, log scale)')
plt.xlabel('Depth Level')
plt.ylabel('Distance Value (log scale)')
plt.legend(title='Order Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# Usually the distance at the 0 level is very close to 0. At levels 1-14 the distance increases gradually.

# %% [markdown]
# ### Calcel Volume

# %%
levels = range(15)
data = []

for i in levels:
    data.append(pd.DataFrame({
        'Level': [i] * len(df) * 2,
        'Type': ['Bid'] * len(df) + ['Ask'] * len(df),
        'Value': pd.concat([df[f'bids_cancel_notional_{i}'], df[f'asks_cancel_notional_{i}']], ignore_index=True)
    }))

df_box_all = pd.concat(data, ignore_index=True)

plt.figure(figsize=(14, 4))
sns.boxplot(
    data=df_box_all,
    x='Level',
    y='Value',
    hue='Type',
    palette={'Bid': 'green', 'Ask': 'red'},
    width=0.6
)

#plt.yscale('log') 
plt.title('Cancellation Notional Distributions per Level (Bid vs Ask)')
plt.xlabel('Depth Level')
plt.ylabel('Cancellation Notional Value')
plt.legend(title='Order Type')
plt.tight_layout()
plt.show()

# %%
df_box_all[df_box_all['Value'] >= max(df_box_all['Value']*0.30)]
# Out:
#         Level Type       Value
# 197154      5  Ask  94993152.0
# 325098      9  Ask  77984176.0

# %% [markdown]
# there are 2 outliers

# %%
df_box_all['Value'] = np.log1p(df_box_all['Value']) # log scale

plt.figure(figsize=(14, 4))
sns.boxplot(
    data=df_box_all,
    x='Level',
    y='Value',
    hue='Type',
    palette={'Bid': 'green', 'Ask': 'red'},
    width=0.6
)

#plt.yscale('log') 
plt.title(f'{asset} {freq} - Cancellation Notional Distributions per Level (log scale)')
plt.xlabel('Depth Level')
plt.ylabel('Cancellation Notional Value (log scale)')
plt.legend(title='Order Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# As already discovered, there are a lot of zeros at the cancelation volumes, therefore for all distributions the medioan is 0.

# %% [markdown]
# ### Limit Volume

# %%
levels = range(15)
data = []

for i in levels:
    data.append(pd.DataFrame({
        'Level': [i] * len(df) * 2,
        'Type': ['Bid'] * len(df) + ['Ask'] * len(df),
        'Value': pd.concat([df[f'bids_limit_notional_{i}'], df[f'asks_limit_notional_{i}']], ignore_index=True)
    }))

df_box_all = pd.concat(data, ignore_index=True)
df_box_all['Value'] = np.log1p(df_box_all['Value']) # log scale

plt.figure(figsize=(14, 4))
sns.boxplot(
    data=df_box_all,
    x='Level',
    y='Value',
    hue='Type',
    palette={'Bid': 'green', 'Ask': 'red'},
    width=0.6
)
#plt.yscale('log') 
plt.title(f'{asset} {freq} - Limits Distributions per Level (log scale)')
plt.xlabel('Depth Level')
plt.ylabel('Limits Value (log scale)')
plt.legend(title='Order Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# Limit volume is higher for 0 level and stable on other levels.

# %% [markdown]
# ### Market Volume

# %%
levels = range(15)
data = []

for i in levels:
    data.append(pd.DataFrame({
        'Level': [i] * len(df) * 2,
        'Type': ['Bid'] * len(df) + ['Ask'] * len(df),
        'Value': pd.concat([df[f'bids_market_notional_{i}'], df[f'asks_market_notional_{i}']], ignore_index=True)
    }))

df_box_all = pd.concat(data, ignore_index=True)

plt.figure(figsize=(14, 4))
sns.boxplot(
    data=df_box_all,
    x='Level',
    y='Value',
    hue='Type',
    palette={'Bid': 'green', 'Ask': 'red'},
    width=0.6
)

#plt.yscale('log') 
plt.title(f'{asset} {freq} - Market Distributions per Level (log scale)')
plt.xlabel('Depth Level')
plt.ylabel('Market Value (log scale)')
plt.legend(title='Order Type')
plt.tight_layout()
plt.show()

# %%
df_box_all[df_box_all['Value'] >= max(df_box_all['Value']*0.30)]
# Out:
#         Level Type         Value
# 10200       0  Bid  9.837830e+05
# 14678       0  Bid  9.446112e+05
# 14910       0  Bid  1.298825e+06
# 16117       0  Bid  8.528251e+05
# 17131       0  Ask  9.457411e+05
# 23844       0  Ask  1.044591e+06
# 26652       0  Ask  1.565690e+06
# 26831       0  Ask  2.611694e+06
# 27747       0  Ask  1.065209e+06
# 27749       0  Ask  8.140813e+05
# 29031       0  Ask  1.273770e+06
# 29032       0  Ask  1.811795e+06
# 29033       0  Ask  1.920088e+06
# 29034       0  Ask  1.234773e+06
# 29219       0  Ask  8.022013e+05
# 29421       0  Ask  1.464586e+06
# 32452       0  Ask  8.566613e+05
# 33674       0  Ask  1.664623e+06
# 63341       1  Ask  8.101196e+05
# 66670       1  Ask  7.980316e+05
# 104663      3  Bid  8.824538e+05
# 129337      3  Ask  1.390769e+06
# 200519      5  Ask  1.352306e+06
# 217860      6  Bid  8.361934e+05
# 220303      6  Bid  1.644546e+06
# 220620      6  Bid  2.547446e+06
# 302950      8  Ask  8.157879e+05
# 322891      9  Bid  1.988410e+06
# 368203     10  Ask  8.589274e+05
# 387635     11  Bid  2.214793e+06
# 443075     12  Ask  8.053248e+05
# 460760     13  Bid  1.402384e+06

# %% [markdown]
# There are some outliers standing out from the general scope.

# %%
df_box_all= df_box_all[df_box_all['Value'] < max(df_box_all['Value']*0.30)]

# %%
df_box_all['Value'] = np.log1p(df_box_all['Value'])

plt.figure(figsize=(14, 4))
sns.boxplot(
    data=df_box_all,
    x='Level',
    y='Value',
    hue='Type',
    palette={'Bid': 'green', 'Ask': 'red'},
    width=0.6
)

#plt.yscale('log') 
plt.title(f'{asset} {freq} - Market Distributions per Level (log scale)')
plt.xlabel('Depth Level')
plt.ylabel('Market Value (log scale)')
plt.legend(title='Order Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# Similary to the Cancel volume, the Market volume shows mainly zero values on the levels 1-14.

# %% [markdown]
# ### Correlation matrix

# %%
corr_features = ['midpoint', 'spread', 'buys', 'sells'] + \
                 [f'bids_notional_{i}' for i in range(3)] + \
                 [f'asks_notional_{i}' for i in range(3)] + \
                 [f'bids_distance_{i}' for i in range(3)] + \
                 [f'asks_distance_{i}' for i in range(3)] + \
                 [f'bids_limit_notional_{i}' for i in range(3)] + \
                 [f'asks_limit_notional_{i}' for i in range(3)]

corr = df[corr_features].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=False, cmap='coolwarm', center=0)
plt.title('Correlation Matrix ({} {})'.format(asset, freq))
plt.show()

# %% [markdown]
# There is a weak positive correlation between spread&sells and buys&sells, which usually make sence it any market.
#
# Also, there is a strong negative correlation between **spread** & **bids_distance_0** and strong positive correlation between **spread** & **asks_distance_0**. (the correlations decreases in absolute values for deeper levels)
#
# There is strong negative correlation between **bids_distance_0** & **asks_distance_0**, whcih is also logically correct, because these features depends on the market activity at the considered time interval.
